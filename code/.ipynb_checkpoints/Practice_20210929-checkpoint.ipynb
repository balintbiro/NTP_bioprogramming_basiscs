# %%
#pseudocode
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#ha beolvasni akarom a fájlt
matrix = pd.read.csv('elérési út')

#ha magamnak akarok létrehozni egy mátrixot

#nested list létrehozása
length_of_stay=[[1,2,3],[1,3,2],[4,6,5],[6,5,7]]

#mátrix létrehozása a nested list-ből
matrix=pd.DataFrame(length_of_stay)

#header elnevezése
matrix.columns=['a_class','b_class','c_class']

#index elnevezése
matrix.index=['COPD', 'asthma', 'allergy', 'sepsis']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-f3c479fe15b7> in <module>
#      16
#      17 #ha beolvasni akarom a fájlt
# ---> 18 matrix = pd.read.csv('elérési út')
#      19
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/__init__.py in __getattr__(name)
#     242         return _SparseArray
#     243
# --> 244     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     245
#     246
#
# AttributeError: module 'pandas' has no attribute 'read'

# %%
length_of_stay
# Out:
# [[1, 2, 3], [1, 3, 2], [4, 6, 5], [6, 5, 7]]

# %%
matrix=pd.DataFrame(length_of_stay)
matrix.columns=['a_class','b_class','c_class']
matrix.index=['COPD', 'asthma', 'allergy', 'sepsis']
matrix
# Out:
#          a_class  b_class  c_class
# COPD           1        2        3
# asthma         1        3        2
# allergy        4        6        5
# sepsis         6        5        7

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
matrix = pd.read_csv('../data/microLab.csv', index_col=0)
matrix
# Out:
#             patientunitstayid  culturetakenoffset                culturesite  \
# microlabid
# 549559                 983524                -688        Blood, Venipuncture
# 549555                 983524               -5481                      Stool
# 549565                 983524                 324                      Stool
# 549562                 983524                -686        Blood, Central Line
# 549564                 983524                -681        Blood, Central Line
# ...                       ...                 ...                        ...
# 1617032               3160582                 411                      Other
# 1617031               3160582                -521        Blood, Venipuncture
# 1617033               3160582                 411                      Other
# 1617030               3160582                -522        Blood, Venipuncture
# 1627296               3160583                  -7  Sputum, Tracheal Specimen
#
# ...

# %%
pathogens=matrix['organism']
pathogens.unique()
# Out:
# array(['gram positive rods', 'no growth', 'gram negative rods',
#        'gram positive cocci', 'mixed flora',
#        'gram positive cocci - in chains', 'Clostridium difficile',
#        'Klebsiella pneumoniae', 'Legionella', 'Streptococcus pneumoniae',
#        'Staphylococcus aureus', 'Escherichia coli',
#        'gram positive cocci - in clusters', 'Other',
#        'Enterococcus fecium', 'Pseudomonas aeruginosa', 'yeast',
#        'Klebsiella oxytoca', 'Enterococcus faecalis', 'Enterobacter sp.',
#        'gram negative cocci', 'Stenotrophomonas maltophila',
#        'Haemophilus influenzae', 'Serratia marcescens',
#        'gram negative diplococci', 'Neisseria meningitides',
#        'Candida glabrata', 'Acinetobacter baumanii', 'Candida albicans',
#        'Aspergillus fumigatus', 'Proteus mirabilis (indole +)',
#        'Corynebacterium sp.', 'Candida tropicalis',
#        'Enterobacter cloacae', 'Streptococcus species, other',
# ...
